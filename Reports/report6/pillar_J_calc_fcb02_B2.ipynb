# %%
target_J = 1 #mA/Cm2
area = 49286136.6 #square micron
area_cm2 = area*1e-4*1e-4
area_cm2
# Out:
# 0.492861366

# %%
optimized_J = 1 #mA/cm2
current_required = area_cm2*optimized_J #gives current in miliampere 
current_required
# Out:
# 0.492861366

# %%
# i get 6um pillar in 2 mins 30 seconds i.e. 150 seconds at a current of 2.8mA.
current_reduction_factor = 2.8/current_required 
current_reduction_factor
# Out:
# 5.6811107405809524

# %%
# so i have to reduce the current by around 5.7 times. in a ideal world
