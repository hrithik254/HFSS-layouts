# %%
import csv
import matplotlib.pyplot as plt

# %%
filename = 'Terminal S11 Parameter Plot1.csv'
fields = []  # Column names
rows = []    # Data rows
freq = []
with open(filename, 'r') as csvfile:
    csvreader = csv.reader(csvfile)  # Reader object

    fields = next(csvreader)  # Read header
    for row in csvreader:     # Read rows
        rows.append(row)

# %%
fields
# Out:
# ['Freq [GHz]',
#  "dB(St(1,1)) [] - dielectric_overlap='1um' pillar_h='10um'",
#  "dB(St(1,1)) [] - dielectric_overlap='1um' pillar_h='50um'",
#  "dB(St(1,1)) [] - dielectric_overlap='200um' pillar_h='50um'",
#  "dB(St(1,1)) [] - dielectric_overlap='205um' pillar_h='50um'"]

# %%
S11_overlap_1_pillarh_10 = []
S11_overlap_1_pillarh_50 = []
