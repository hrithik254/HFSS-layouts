# %%
t = """3
AhheioIehHA
OeaiensneIaIeO
wieowppwoeiw"""
print(t)
# Out:
# 3
# AhheioIehHA
# OeaiensneIaIeO
# wieowppwoeiw

# %%
k = input()
k
# Out:
# 3/AhheioIehHA/OeaiensneIaIeO/wieowppwoeiw
# '3/AhheioIehHA/OeaiensneIaIeO/wieowppwoeiw'
