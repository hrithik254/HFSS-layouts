# %%
import math as m
from matplotlib import pyplot as plt
import numpy as np

# %%
planned = [1200, 1300,1400]
actual = [0,92.4,210.4]
plt.plot(planned,actual, linestyle = 'none', marker = 'o')
plt.ylim([-1,500])
plt.xlabel('Planned Gate Length')
plt.ylabel('Achieved Gate Length')
plt.grid()
# plt.plot((0,1000),(0,1000))
