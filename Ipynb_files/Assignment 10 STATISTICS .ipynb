# %% [markdown]
# # Q1
# ## (a)

# %%
def normal(a=0,b=0,c=0):
    g(x) = (c*sqrt(pi*2))*(exp(-((x-a)**2)/(2*(b**2))))
    return g(x)
plot(normal(av3,sd3,g.ymax()/sqrt(2*pi)),x,0,25)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-df3ed7d30b7f> in <module>()
#       2     __tmp__=var("x"); g = symbolic_expression((c*sqrt(pi*Integer(2)))*(exp(-((x-a)**Integer(2))/(Integer(2)*(b**Integer(2)))))).function(x)
#       3     return g(x)
# ----> 4 plot(normal(av3,sd3,g.ymax()/sqrt(Integer(2)*pi)),x,Integer(0),Integer(25))
#
# NameError: name 'av3' is not defined

# %%
import os
import matplotlib.pyplot as plt
path = r'C:\Users\Hrithik Singla\Desktop'
file1 = 'covid.csv'
txt_file1 = open((os.path.join(path,file1)) , 'r')
dates1 = []
cases1 = []
casestot1 = []
line1 = txt_file1.readline()
line1 = txt_file1.readline()
while len(line1) > 0:
    elements1 = line1.split(',')
    dates1.append(elements1[0].strip())
    cases1.append(int(elements1[1].strip()))
    casestot1.append(elements1[2].strip())
    line1 = txt_file1.readline()
txt_file1.close()

casestot1 = [int(casestot1[i]) for i in range(len(casestot1))]

fig , (p1,p2) = plt.subplots(ncols = 1, nrows = 2, figsize =(50,40))

p1.set_title('INDIA total cases v Dates' , size = 30)
p1.tick_params(axis = 'y',labelsize = 25)
p1.tick_params(axis = 'x' , labelsize = 20)
p1.bar(dates1,casestot1)

p2.set_title('India New Cases V Dates' , size = 30)
p2.tick_params(axis = 'y', labelsize = 25)
p2.tick_params(axis = 'x' , labelsize = 20)
p2.bar(dates1,cases1)

casestot1.append(int(39000))
cases1.append(int(1900))

#loop to calculate weekely rate  assuming compound interest
weekly_rate1 = []
weekly_ratenew = [] #rate of increase of new cases per day

for i in range(0,6):
    c1 = ((casestot1[7*i +7]/casestot1[7*i])**(1/7)-1)*100
    weekly_rate1.append(str(n(c1,digits = 4)) + ' %') 
    
    #for weekely rates of the new cases plot
    c2 = ((cases1[7*i +7]/cases1[7*i])**(1/7)-1)*100
    weekly_ratenew.append(str(n(c2 , digits = 4)) + ' %')

print(weekly_rate1)    
print(weekly_ratenew)
# Out:
# ['16.11 %', '19.56 %', '13.06 %', '9.668 %', '7.603 %', '5.921 %']
# ['4.672 %', '24.98 %', '8.913 %', '5.371 %', '5.879 %', '3.348 %']

# %%
file2 = 'statecovid.csv'
txt_file2 = open((os.path.join(path,file2)) , 'r')

dates2 = []
cases2 = []
casestot2 = []
line1 = txt_file2.readline()
line1 = txt_file2.readline()

while len(line1) > 0:
    elements2 = line1.split(',')
    dates2.append(elements2[0].strip())
    cases2.append(int(elements2[1].strip()))
    casestot2.append(elements2[2].strip())
    line1 = txt_file2.readline()
txt_file2.close()

casestot2 = [int(casestot2[i]) for i in range(len(casestot2))]

fig2,(p3,p4) = plt.subplots(ncols =1 ,nrows = 2,  figsize = (25,30))

p3.set_title('Haryana total cases v dates', size = 30)
p3.tick_params(axis = 'y', labelsize = 20)
p3.bar(dates2,casestot2)

p4.set_title('Haryana New Cases V Dates' , size = 30)
p4.tick_params(axis = 'y' , labelsize = 20)
p4.bar(dates2,cases2)

#loop to calculate the weekly rates in two ways
weekly_rate2 = []
weekly_rate2new = []

for i in range(0,5):
    c = ((casestot2[7*i +7]/casestot2[7*i])**(1/7)-1)*100 
    weekly_rate2.append(str(n(c , digits = 4)) + ' %')
    
print(weekly_rate2)
# Out:
# ['6.670 %', '8.655 %', '17.73 %', '3.350 %', '3.125 %']

# %% [markdown]
# # Q2
# ## (a)

# %%
var('x,y')
a = 1
b = 1
f(x) = exp(-2((x-a)**2))/sqrt(2*pi)
c = (1/integral(f(x),x,-oo,oo))
show(c)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-8ecb5be07b51> in <module>()
#       2 a = Integer(1)
#       3 b = Integer(1)
# ----> 4 __tmp__=var("x"); f = symbolic_expression(exp(-Integer(2)((x-a)**Integer(2)))/sqrt(Integer(2)*pi)).function(x)
#       5 c = (Integer(1)/integral(f(x),x,-oo,oo))
#       6 show(c)
#
# TypeError: 'sage.rings.integer.Integer' object is not callable

# %% [markdown]
# ## (b)

# %%
#we know the total area is one 
#(−∞, ∞),(−∞, −2),(−∞, −1),(−∞, 0),(−∞, 1),(−∞, 2),(−1, 1),(−2, 2),(1, ∞),(2, ∞)

s1 = 'In the interval '
intervals = ['(−∞, ∞)','(−∞, −2)','(−∞, −1)','(−∞, 0)','(−∞, 1)','(−1, 1)','(−2, 2)','(1, ∞)','(2, ∞)','(−∞, 2)']


a1 = float(integral(c*y,x,-oo,oo)*100)/1.0
a2 = float(integrate(c*y,x,-oo,-2)*100)/1.0
a3 = float(integrate(c*y,x,-oo,-1)*100)/1.0
a4 = float(integrate(c*y,x,-oo,0)*100)/1.0
a5 = float(integrate(c*y,x,-oo,1)*100)/1.0

# using symmetry as function is even and hence symmetric about y
a6 = 2*float(integrate(c*y,x,0,1)*100)/1.0
a7 = 2*float(integrate(c*y,x,0,2)*100)/1.0

a8 = float(integrate(c*y,x,1,oo)*100)/1.0
a9 = float(integrate(c*y,x,2,oo)*100)/1.0
a10 =float(integrate(c*y,x,-oo,2)*100)/1.0
print(a1,s1,intervals[0])
print(a2,s1,intervals[1])
print(a3,s1,intervals[2])
print(a4,s1,intervals[3])
print(a5,s1,intervals[4])
print(a6,s1,intervals[5])
print(a7,s1,intervals[6])
print(a8,s1,intervals[7])
print(a9,s1,intervals[8])
print(a10,s1,intervals[9])

plot(c*y,-4,4)

# %% [markdown]
# ## (c)

# %%
a = 2
b = 3
c = 5
total_area = (integral(c*y,x,-oo,oo))
print('Total area is ' + str(total_area))

a1 = float(integral(c*y,x,-oo,oo)*100)/total_area
a2 = float(integrate(c*y,x,-oo,-2)*100)/total_area

a3 = float(integrate(c*y,x,-oo,-1)*100)/total_area
a4 = float(integrate(c*y,x,-oo,0)*100)/total_area

a5 = float(integrate(c*y,x,-oo,1)*100)/total_area
a6 = 2*float(integrate(c*y,x,0,1)*100)/total_area

a7 = 2*float(integrate(c*y,x,0,2)*100)/total_area
a8 = float(integrate(c*y,x,1,oo)*100)/total_area
a9 = float(integrate(c*y,x,2,oo)*100)/total_area
a10 =float(integrate(c*y,x,-oo,2)*100)/total_area

show('The areas in the concerned intervals as a percentage of the total area is given as follows ')
print(a1,s1,intervals[0])
print(a2,s1,intervals[1])
print(a3,s1,intervals[2])
print(a4,s1,intervals[3])
print(a5,s1,intervals[4])
print(a6,s1,intervals[5])
print(a7,s1,intervals[6])
print(a8,s1,intervals[7])
print(a9,s1,intervals[8])
print(a10,s1,intervals[9])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-df8d4cc68d07> in <module>()
#       2 b = Integer(3)
#       3 c = Integer(5)
# ----> 4 total_area = (integral(c*y,x,-oo,oo))
#       5 print('Total area is ' + str(total_area))
#       6
#
# NameError: name 'y' is not defined

# %%
@interact
def go(f1= c*exp(-((x-a)**2)/(2*(b**2))),f2 = 0.4*(exp(-((x-0)**2)/(2*(1**2)))) ,a=slider(-10,10,0.1,default = 0) 
       , b = slider(-10,10,0.1,default = 1) , c = slider(-10,10,0.1,default = 0.3989) ):
    
    p1=plot(c*f1,(x,-2,2) , legend_label = 'modified' , color = 'yellow')
    
    p2=plot(0.40*(exp(-((x-0)**2)/(2*(1**2)))) ,(x,-3,3) , color = 'green' , legend_label = 'Ideal Curve')
    
    show(p1+p2)
    
a1 = float(integral(c*y,x,-oo,oo)*100)
print(a1)

# %% [markdown]
# # Q3
# ## (a)

# %%
file3 = 'midterm.csv'
txt_file3 = open(os.path.join(path,file3) , 'r')
line = txt_file3.readline()
line = txt_file3.readline()
minor=[]
internal=[]
midterm=[]

while len(line)>0:
    marks_list = line.split(',')
    internal.append(int(marks_list[1].strip()))
    minor.append(int(marks_list[2].strip()))
    midterm.append(int(marks_list[3].strip()))
    line = txt_file3.readline()
av1 = mean(internal)
av2 = mean(minor)
av3 = mean(midterm)
sd1 = std(internal)
sd2 = std(minor)
sd3 = std(midterm)


h1 = histogram(midterm , title = 'Histogram for midterm scores', alpha = 0.9 , color = 'yellow' )
h1 += plot(normal(av3,sd3,h1.ymax()/sqrt(2*pi)),x,0,25)
h1 += line2d([(av3,0),(av3,60)] , color = 'brown' , linestyle = 'dashed' , thickness = 2 , legend_label = 'mean')


show('the mean is ' + str(av3.n(digits = 4)) + '\nThe Standard Deviation is ' + str(sd3.n()))
show(h1)
print(n(av1),n(av2),n(sd1),n(sd2))
# Out:
# 'the mean is 9.700\nThe Standard Deviation is 4.34170705691520'
# Graphics object consisting of 3 graphics primitives
# 3.74166666666667 6.06666666666667 1.99366995462017 3.06986801603169

# %% [markdown]
# ## (b)

# %%
s1 = scatter_plot(list(zip(internal,minor)) , title = "Scatter Plot ")
f(x) = x*(sd2/sd1)
s1 += plot(f(x),(0,max(internal)) , color = 'green' ,
        linestyle ='dashed',thickness = 2,legend_label = ' The SD line')
s1 += line2d([(0,av2),(max(internal),av2)] , legend_label = 'Average line')
s1 += line2d([(av1,0),(av1,max(minor))])

p = r.cor(internal,minor)
print('the correlation is ' + str(p))

s1.axes_labels(['Internal','Minor'] )
s1.show()

# %% [markdown]
# ## (c)

# %%
def experiment():
    marks = []
    dict1 = {'Standard_Er': 0 , 'Average' : 0 , ' Actual Mean' : av3.n(digits = 2)}
    for i in range(20):
        marks.append(midterm[randint(0,119)])
    sd = n(std(marks), digits = 3)
    av = n(mean(marks), digits =3)
    dict1['Standard_Er'] = N(sd/sqrt(20) , digits = 3)
    confidence_interval = 2*N(sd/sqrt(20) , digits = 3)
    dict1['Average'] = str(av) + ' ±' + str(confidence_interval)
    return dict1, av-av3

error = []
for i in range(5):
    dict1 , k = experiment()
    error.append(k)
    show(dict1)
print('The standard deviation of error in mean estimation is ' + str(std(error)))

# %% [markdown]
# ## (d)

# %%
Marks = [0,1,2,3,4,5]
Random_Scores = []
for i in range(120):
    sum = 0
    for j in range(5):
        sum += Marks[randint(0,5)]
    Random_Scores.append(sum)
    

av_random = mean(Random_Scores)
std_random = std(Random_Scores)
show(av_random.n())
g = histogram(Random_Scores, title = 'Histogram for random midterm scores', alpha = 0.9 , color = 'yellow' )
g += line2d([(av_random,0),(av_random,g.ymax())] , color = 'green',
           linestyle = 'dashed' , thickness = 3 , legend_label = 'Mean')
g += plot(normal(av_random,std_random,g.ymax()/sqrt(2*pi)),x,g.xmin(),g.xmax())
print(std(Random_Scores).n())

count= 0
for i in range(len(Random_Scores)):
    if(av_random-std(Random_Scores)<=Random_Scores[i] <= av_random +std(Random_Scores)):
        count += 1
print('The fraction of values in +- 1 SD is ' + str(N(count/120)))

count= 0
for i in range(len(Random_Scores)):
    if(av_random-2*std(Random_Scores)<=Random_Scores[i] <= av_random +2*std(Random_Scores)):
        count += 1
print('The fraction of values in +- 2 SD is ' + str(N(count/120)))
g.show()
# Out:
# 12.0666666666667
# 3.78349652284436
# The fraction of values in +- 1 SD is 0.616666666666667
# The fraction of values in +- 2 SD is 0.975000000000000
# Graphics object consisting of 3 graphics primitives

# %%
def experiment():
    marks = []
    dict1 = {'Standard_Er': 0 , 'Average' : 0 , ' Actual Mean' : av_random.n(digits = 4)}
    for i in range(20):
        marks.append(Random_Scores[randint(0,119)])
    sd = n(std(marks), digits = 3)
    av = n(mean(marks), digits =3)
    dict1['Standard_Er'] = N(sd/sqrt(20) , digits = 3)
    confidence_interval = 2*N(sd/sqrt(20) , digits = 3)
    dict1['Average'] = str(av) + ' ±' + str(confidence_interval)
    return dict1, av-av3

error = []
for i in range(5):
    dict1 , k = experiment()
    error.append(k)
    show(dict1)
print('The standard deviation of error in mean estimation is ' + str(std(error)))
# Out:
# {'Standard_Er': 0.908, 'Average': '10.5 ±1.82', ' Actual Mean': 12.07}
# {'Standard_Er': 0.755, 'Average': '12.8 ±1.51', ' Actual Mean': 12.07}
# {'Standard_Er': 0.851, 'Average': '12.0 ±1.70', ' Actual Mean': 12.07}
# {'Standard_Er': 0.816, 'Average': '11.5 ±1.63', ' Actual Mean': 12.07}
# {'Standard_Er': 0.815, 'Average': '11.7 ±1.63', ' Actual Mean': 12.07}
# The standard deviation of error in mean estimation is 0.838

# %% [markdown]
# ## (e)

# %% [markdown]
# ## COVID -19 testing analysis India

# %%
file4 = 'testing COVID-19 India.csv'
txt_file4 = open(os.path.join(path,file4) , 'r')
line = txt_file4.readline()
line = txt_file4.readline()
test_daily = []
test_total = []
dates3 = []



while len(line) > 0:
    elements = line.split(',')
    dates3.append(elements[0].strip())
    test_daily.append(int(elements[1].strip()))
    test_total.append(int(elements[2].strip()))
    line = txt_file4.readline()
txt_file4.close()

plt.figure(figsize = (25,10))
#r = plt.scatter(dates3,test_total)
show(r)
k = plt.plot(dates3,test_daily)
show(k)
plt.yticks(fontsize = 20)

weekly_rate_tests = []
for i in range(0,7):
    c = ((test_total[7*i +7]/test_total[7*i])**(1/7)-1)*100 
    weekly_rate_tests.append(str(n(c , digits = 4)) + ' %')
print(weekly_rate_tests)

show(r,k)
# Out:
# <html><script type="math/tex; mode=display">\newcommand{\Bold}[1]{\mathbf{#1}}\verb|<matplotlib.collections.PathCollection|\phantom{\verb!x!}\verb|object|\phantom{\verb!x!}\verb|at|\phantom{\verb!x!}\verb|0x6ffe93ab74e0>|</script></html>
# <html><script type="math/tex; mode=display">\newcommand{\Bold}[1]{\mathbf{#1}}\left[\verb|Line2D(_line0)|\right]</script></html>
# ['44.79 %', '19.24 %', '16.07 %', '11.63 %', '8.860 %', '7.664 %', '6.932 %']
# <matplotlib.collections.PathCollection object at 0x6ffe93ab74e0> [<matplotlib.lines.Line2D object at 0x6ffe920840b8>]

# %%
var('x')
f(x) = (1/sqrt(2*pi*))*exp((x-119.27)/)
